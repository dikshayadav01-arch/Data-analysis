# %%
! pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Diksha\Downloads\Used_Bikes.csv")

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df[(df['brand']=='TVS')&(df['kms_driven']<=75000)&(df['age']<=2)&(df['price']<=50000)]
# Out:
#             bike_name    price       city  kms_driven        owner  age  \
# 7055  TVS Sport 100cc  46000.0  Faridabad      6222.0  First Owner  2.0
#
#       power brand
# 7055  100.0   TVS

# %%
df.query("brand == 'TVS' and age <= 2 and price <= 50000 and kms_driven <= 75000")
# Out:
#             bike_name    price       city  kms_driven        owner  age  \
# 7055  TVS Sport 100cc  46000.0  Faridabad      6222.0  First Owner  2.0
#
#       power brand
# 7055  100.0   TVS

# %%
df['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth Owner Or More'], dtype=object)

# %%
owner_bike={
    'First Owner':1, 'Second Onwer':2, 'Third Owner':3, 'Fourth Owner or More':4
    }

# %%
df['owner'].map(owner_bike)
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 32643    1.0
# 32644    1.0
# 32645    1.0
# 32646    1.0
# 32647    1.0
# Name: owner, Length: 32648, dtype: float64

# %%
x=df.drop('price', axis=1)
y=df[['price']]

# %%
y
# Out:
#           price
# 0       35000.0
# 1      119900.0
# 2      600000.0
# 3       65000.0
# 4       80000.0
# ...         ...
# 32643   39000.0
# 32644   30000.0
# 32645   60000.0
# 32646   15600.0
# 32647   22000.0
#
# [32648 rows x 1 columns]

# %%
! pip install scikit-learn

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20432\885825953.py in ?()
#       1 from sklearn.linear_model import LinearRegression
#       2 lr=LinearRegression()
# ----> 3 lr.fit(x,y)
#
# c:\Users\Diksha\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1332                 skip_parameter_validation=(
#    1333                     prefer_skip_nested_validation or global_skip_validation
#    1334                 )
#    1335             ):
# -> 1336                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\Diksha\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     626         n_jobs_ = self.n_jobs
#     627
#     628         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
xpoint=np.array([1,2,3,5])
ypoint=np.array([2,4,6,8])
plt.xlabel('price')
plt.ylabel=('count')
plt.title('matplotlib')
plt.grid()
plt.plot(xpoint,ypoint)
plt.show()

# %%
xpoint=np.array([1,2,3,5])
ypoint=np.array([2,4,6,8])
plt.xlabel('price')
plt.ylabel=('count')
plt.title('matplotlib')
plt.grid()
plt.plot(xpoint,ypoint)
plt.show()

# %%
xpoint=np.array([1,2,3,5])
ypoint=np.array([2,4,6,8])
plt.subplot(1,2,1)
plt.plot(xpoint,ypoint)
xxpoint=np.array([1,2,2,5])
yypoint=np.array([2,4,6,8])
plt.subplot(1,2,2)
plt.plot(xxpoint, yypoint)
plt.show()

# %%
xpoint=np.array([1,2,3,5])
ypoint=np.array([2,4,6,8])
plt.scatter(xpoint,ypoint)
plt.show()
