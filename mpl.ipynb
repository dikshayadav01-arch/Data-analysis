# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x=np.array([1,2,3,4])
y=np.array([2,4,6,8])

# %%
plt.plot(x,y)
plt.show()

# %%
x=np.array([0,6])
y=np.array([0,3])
plt.plot(x,y, 'o')
plt.show()

# %%
x=np.array([0,6])
y=np.array([0,3])
plt.plot(x,y, marker='o')
plt.show()

# %%
#x=np.array([0,6])
y=np.array([0,3])
plt.plot(y, marker= 'o')
plt.show()

# %%
x=np.array([0,6])
y=np.array([0,3])
plt.plot(y, marker='*')
plt.show()

# %%
x=np.array([0,6])
y=np.array([0,3])
plt.plot(y,'o:b')
plt.show()

# %%
#x=np.array([0,6])
y=np.array([2,4,6,8])
plt.plot(y, marker='*', ms=20)
plt.show()

# %%
#x=np.array([0,6])
y=np.array([2,4,6,8])
plt.plot(y, marker='*', ms=20, mec='r')
plt.show()

# %%
#x=np.array([0,6])
y=np.array([2,4,6,8])
plt.plot(y, marker='*', ms=20, mec='r', mfc='green')
plt.show()

# %%
xpoint=np.array([1,2,2,5])
plt.plot(xpoint, ls='dotted')
plt.show()

# %%
xpoint=np.array([1,2,2,5])
plt.plot(xpoint, ls='dashed')
plt.show()

# %%
xpoint=np.array([1,2,2,5])
plt.plot(xpoint, linewidth=20)
plt.show()

# %%
xpoint=np.array([1,2,3,5])
ypoint=np.array([2,4,6,8])

plt.plot(x)
plt.plot(y)
plt.show()

# %%
xpoint=np.array([1,2,3,5])
ypoint=np.array([2,4,6,8])
plt.xlabel('price')
plt.ylabel=('count')
plt.title('matplotlib')
plt.plot(xpoint,ypoint)
plt.show()

# %%
xpoint=np.array([1,2,3,5])
ypoint=np.array([2,4,6,8])
plt.scatter(xpoint,ypoint)
plt.show()

# %%
xpoint=np.array([1,2,3,5])
ypoint=np.array([2,4,6,8])
plt.xlabel('price')
plt.ylabel=('count')
plt.title('matplotlib')
plt.grid()
plt.plot(xpoint,ypoint)
plt.show()

# %%
xpoint=np.array([1,2,3,5])
ypoint=np.array([2,4,6,8])
plt.subplot(1,2,1)
plt.plot(xpoint,ypoint)
xxpoint=np.array([1,2,2,5])
yypoint=np.array([2,4,6,8])
plt.subplot(1,2,2)
plt.plot(xxpoint, yypoint)
plt.show()

# %%
x=[1,2,3,4]
y=[2,4,6,8]
plt.scatter(x,y)
xpoint=[3,6,9,12]
ypoint=[4,8,12,16]
plt.scatter(xpoint,ypoint)
plt.show()

# %%
x=np.array([1,2,3,4])
y=np.array([2,4,6,8])
c=np.array(['red','blue','black','yellow'])
plt.scatter(x,y,c=c)
plt.show()

# %%
x=np.array([1,2,3,4])
y=np.array([2,4,6,8])
size=np.array([50,100,75,150])
c=np.array(['red','blue','black','yellow'])
plt.scatter(x,y,c=c,s=size)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y, s = sizes, c = c )
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y, s = sizes, c = c, alpha=0.5, cmap='coolwarm' )
plt.show()
# Out:
# C:\Users\Diksha\AppData\Local\Temp\ipykernel_4088\3167122780.py:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, s = sizes, c = c, alpha=0.5, cmap='coolwarm' )

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y, s = sizes, c = c, alpha=0.5, cmap='coolwarm' )
plt.colorbar()
plt.show()
# Out:
# C:\Users\Diksha\AppData\Local\Temp\ipykernel_4088\2029395462.py:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, s = sizes, c = c, alpha=0.5, cmap='coolwarm' )

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.bar(x,y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.barh(x,y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.barh(x,y,color='green')
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.bar(x,y,color=c)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.bar(x,y,color=c, width=0.1)
plt.show()

# %%
x=np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %%
x=np.array([1,2,3,4])
plt.pie(x)
plt.show()

# %%
x=np.array([1,2,3,4])
lable=np.array(['CO2','N2','O2','He'])
plt.pie(x, labels=lable, startangle=90)
plt.show()

# %%
x=np.array([1,2,3,4])
lable=np.array(['CO2','N2','O2','He'])
myecplod=np.array([0.2,0,0,0])
plt.pie(x, labels=lable, startangle=90, explode=myecplod)
plt.show()

# %%
x=np.array([1,2,3,4])
lable=np.array(['CO2','N2','O2','He'])
myecplod=np.array([0.2,0,0,0])
plt.pie(x, labels=lable, startangle=90, explode=myecplod, shadow=True)
plt.show()

# %%
x=np.array([1,2,3,4])
lable=np.array(['CO2','N2','O2','He'])
myecplod=np.array([0.2,0,0,0])
c=np.array(['red','green','black','pink'])
plt.pie(x, labels=lable, startangle=90, explode=myecplod, shadow=True,colors=c)
plt.show()

# %%
x=np.array([1,2,3,4])
lable=np.array(['CO2','N2','O2','He'])
myecplod=np.array([0.2,0,0,0])
c=np.array(['red','green','blue','pink'])
plt.pie(x, labels=lable, startangle=90, explode=myecplod, shadow=True,colors=c, autopct="%1.f%%")
plt.show()

# %%
x=np.array([1,2,3,4])
lable=np.array(['CO2','N2','O2','He'])
myecplod=np.array([0.2,0,0,0])
c=np.array(['red','green','blue','pink'])
plt.pie(x, labels=lable, startangle=90, explode=myecplod, shadow=True,colors=c, autopct="%1.f%%")
plt.legend('mypi')
plt.show()

# %%
x=np.array([1,2,3,4])
lable=np.array(['CO2','N2','O2','He'])
myecplod=np.array([0.2,0,0,0])
c=np.array(['red','green','blue','pink'])
plt.pie(x, labels=lable, startangle=90, explode=myecplod, shadow=True,colors=c, autopct="%1.f%%")
plt.legend()
plt.show()
